# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("test.csv")

# %%
df
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x2318    COIMBRES13DEL01                 NaN                     NaN
# 1      0x3474     BANGRES15DEL01                   28                     4.6
# 2      0x9420      JAPRES09DEL03                   23                     4.5
# 3      0x72ee      JAPRES07DEL03                   21                     4.8
# 4      0xa759     CHENRES19DEL01                   31                     4.6
# ...        ...                ...                 ...                     ...
# 11394  0x6909      JAPRES01DEL01                   35                     4.6
# 11395  0x443b      JAPRES11DEL01                   33                     4.9
# 11396  0x1ea5      SURRES11DEL03                 NaN                     NaN
# 11397  0x22d4      VADRES03DEL02                   27                     4.7
# 11398  0xb7be     CHENRES07DEL02                   39                       5
#
# ...

# %%
def data(df):
    df.replace({"NaN": np.nan}, regex=True, inplace = True)
    df.drop(['Time_Order_picked','Delivery_person_ID','Type_of_order','Festival'],axis=1,inplace=True)
    # df['Time_taken(min)'] = df['Time_taken(min)'].str.replace('(min)','')
    df=df.rename(columns={'Time_taken(min)':'Time_taken'})
    df['Weatherconditions']=df['Weatherconditions'].str.replace('conditions','')
    df['Delivery_person_Age']=df['Delivery_person_Age'].astype(float)
    df['Delivery_person_Ratings']=df['Delivery_person_Ratings'].astype(float)
    df['Order_Date']=pd.to_datetime(df['Order_Date'],dayfirst=True)
    df['Time_Orderd'] = pd.to_datetime(df['Time_Orderd'], format='%H:%M:%S', errors='coerce').dt.time
    df = df.rename(columns={
        'Restaurant_latitude': 'translogi_latitude',
        'Restaurant_longitude': 'translogi_longitude'
    })
    return df

# %%
df = data(df)

# %%
df
# Out:
#             ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      0x2318                   NaN                      NaN
# 1      0x3474                  28.0                      4.6
# 2      0x9420                  23.0                      4.5
# 3      0x72ee                  21.0                      4.8
# 4      0xa759                  31.0                      4.6
# ...        ...                  ...                      ...
# 11394  0x6909                  35.0                      4.6
# 11395  0x443b                  33.0                      4.9
# 11396  0x1ea5                   NaN                      NaN
# 11397  0x22d4                  27.0                      4.7
# 11398  0xb7be                  39.0                      5.0
#
#        translogi_latitude  translogi_longitude  Delivery_location_latitude  \
# 0               11.003669            76.976494                   11.043669
# 1               12.975377            77.696664                   13.085377
# ...

# %%
df.to_csv("test.csv", index=False)

# %%
df_output = pd.read_csv("Sample_Submission.csv")

df["Time_taken"] = df_output["Time_taken"]

# %%
df.to_csv("test.csv", index=False)

# %%
import pandas as pd
import numpy as np 

df = pd.read_csv("test.csv")

# %%
df['City'].fillna("unknown")
# Out:
# 0        Metropolitian
# 1        Metropolitian
# 2        Metropolitian
# 3        Metropolitian
# 4        Metropolitian
#              ...
# 11394    Metropolitian
# 11395    Metropolitian
# 11396    Metropolitian
# 11397    Metropolitian
# 11398            Urban
# Name: City, Length: 11399, dtype: object

# %%
df['City'].unique()
# Out:
# array(['Metropolitian', 'Urban', nan, 'Semi-Urban'], dtype=object)
